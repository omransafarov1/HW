# %%
#First execute this cell go to Runtime and click on Restart Runtime
# !pip install --upgrade --no-deps statsmodels
# !pip install tbats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.13.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tbats in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tbats) (1.21.6)
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.7/dist-packages (from tbats) (1.8.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from tbats) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tbats) (1.4.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (0.29.30)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (1.1.0)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (0.13.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (57.4.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima->tbats) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima->tbats) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima->tbats) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima->tbats) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->tbats) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima->tbats) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima->tbats) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima->tbats) (3.0.9)

# %%
import pandas as pd
from matplotlib import pyplot
ap1=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/h02.csv')
ap1=ap1.set_index('Month')
ap1.plot()
pyplot.show()

# %%
ap1
# Out:
#               Cost
# Month
# 1991 Jul  0.429795
# 1991 Aug  0.400906
# 1991 Sep  0.432159
# 1991 Oct  0.492543
# 1991 Nov  0.502369
# ...            ...
# 2008 Feb  0.761822
# 2008 Mar  0.649435
# 2008 Apr  0.827887
# 2008 May  0.816255
# 2008 Jun  0.762137
#
# [204 rows x 1 columns]

# %%
'''
Using the above data set 
1)Test stationary of the dataset.Write hypothesis. 
What is your conclusion at 5% siginifance level?

2)Take difference and seasonal difference and test stationay of the dataset.Write hypothesis. 
What is your conclusion at 5% siginifance level?

3) Plot ACF and PACF of series if series' difference and seasonal difference taken .

4) Based on the plot of ACF and PACF, come up with two SARIMA model and compare their Akaike Information Criteri metric.

5)Split data into train and test. For the test data, use last 12 months observation.

6)Plot test, train and forecast values for the SARIMA model chosen at Q4. 
Evaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).

7) Which model is suitable for Holt Winters' method (Multiplicative or Additive).Briefly explain why? 
Plot test, train and forecast values for the Holt Winters' method.
Evaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).

8) Which model is suitable for ETS method (Multiplicative or Additive for seasonal, trend and error companent. Do we have dampened model or not. ).
Briefly explain why? Plot test, train and forecast values for the ETS method. Evaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).

9) Use TBATS model in train data. Evaluate performance of the model in test data Plot test, train and forecast values for the TBATS method.
 in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).

10) Which model gives the lowes MAPE score?
'''
# Out:
# "\nUsing the above data set \n1)Test stationary of the dataset.Write hypothesis. \nWhat is your conclusion at 5% siginifance level?\n\n2)Take difference and seasonal difference and test stationay of the dataset.Write hypothesis. \nWhat is your conclusion at 5% siginifance level?\n\n3) Plot ACF and PACF of series if series' difference and seasonal difference taken .\n\n4) Based on the plot of ACF and PACF, come up with two SARIMA model and compare their Akaike Information Criteri metric.\n\n5)Split data into train and test. For the test data, use last 12 months observation.\n\n6)Plot test, train and forecast values for the SARIMA model chosen at Q4. \nEvaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).\n\n7) Which model is suitable for Holt Winters' method (Multiplicative or Additive).Briefly explain why? \nPlot test, train and forecast values for the Holt Winters' method.\nEvaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).\n\n8) Which model is suitable for ETS method (Multiplicative or Additive for seasonal, trend and error companent. Do we have dampened model or not. ).\nBriefly explain why? Plot test, train and forecast values for the ETS method. Evaluate performance of the model in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).\n\n9) Use TBATS model in train data. Evaluate performance of the model in test data Plot test, train and forecast values for the TBATS method.\n in terms of MAE(mean absulate error), MAPE(mean absulate percentage error) and MSE(Mean squared Error).\n\n10) Which model gives the lowes MAPE score?\n"

# %%
'''Question1'''
# Out:
# 'Question1'

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

#plot autocorrelation function
fig = tsaplots.plot_acf(ap1, lags=12)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

result = adfuller(ap1['Cost'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.696756
# p-value: 0.432785
# Critical Values:
# 	1%: -3.466
# 	5%: -2.877
# 	10%: -2.575

# %%
ap1
# Out:
#               Cost
# Month
# 1991 Jul  0.429795
# 1991 Aug  0.400906
# 1991 Sep  0.432159
# 1991 Oct  0.492543
# 1991 Nov  0.502369
# ...            ...
# 2008 Feb  0.761822
# 2008 Mar  0.649435
# 2008 Apr  0.827887
# 2008 May  0.816255
# 2008 Jun  0.762137
#
# [204 rows x 1 columns]

# %%
'''Ho:Series is not stationary Ha:Series is stationary Reject null hyphotesis'''
# Out:
# 'Ho:Series is not stationary Ha:Series is stationary Reject null hyphotesis'

# %%
dap = ap1 - ap1.shift(1)

from statsmodels.tsa.stattools import adfuller
dap=dap.dropna()
result = adfuller(dap['Cost'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
 
dap = dap - dap.shift(12)
dap.plot()
# Out:
# ADF Statistic: -3.365938
# p-value: 0.012176
# Critical Values:
# 	1%: -3.466
# 	5%: -2.877
# 	10%: -2.575

# %%
from statsmodels.tsa.stattools import adfuller
dap=dap.dropna()
result = adfuller(dap['Cost'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.070403
# p-value: 0.000016
# Critical Values:
# 	1%: -3.468
# 	5%: -2.878
# 	10%: -2.576

# %%
'''
Ho:Series is not stationary 
Ha:Series is stationary

 Accept null hyphotesis 
'''
# Out:
# '\nHo:Series is not stationary \nHa:Series is stationary\n\n Accept null hyphotesis \n'

# %%
ap2 = ap1.copy()
ap2['6-month-SMA'] = ap2['Cost'].rolling(window=6).mean()
ap2['12-month-SMA'] = ap2['Cost'].rolling(window=12).mean()
ap2.plot(title='Simple Moving Averages');

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt
fig = tsaplots.plot_acf(dap['Cost'], lags=36)
plt.show()
fig = tsaplots.plot_pacf(dap['Cost'], lags=36)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(ap1['Cost'],order=(0,1,1),seasonal_order=(0,1,1,12))
model_fit=model.fit()
model_fit.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               Cost   No. Observations:                  204
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 12)   Log Likelihood                 279.164
# Date:                            Wed, 25 May 2022   AIC                           -552.329
# Time:                                    15:51:45   BIC                           -542.572
# Sample:                                07-01-1991   HQIC                          -548.377
#                                      - 06-01-2008
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7581      0.046    -16.443      0.000      -0.848      -0.668
# ma.S.L12      -0.5650      0.056    -10.177      0.000      -0.674      -0.456
# sigma2         0.0031      0.000     10.054      0.000       0.002       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.14   Jarque-Bera (JB):                 1.60
# Prob(Q):                              0.14   Prob(JB):                         0.45
# Heteroskedasticity (H):               2.31   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(ap1['Cost'],order=(1,1,1),seasonal_order=(0,1,0,12))
model_fit=model.fit()
model_fit.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                Cost   No. Observations:                  204
# Model:             SARIMAX(1, 1, 1)x(0, 1, [], 12)   Log Likelihood                 264.817
# Date:                             Wed, 25 May 2022   AIC                           -523.634
# Time:                                     15:51:46   BIC                           -513.878
# Sample:                                 07-01-1991   HQIC                          -519.682
#                                       - 06-01-2008
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2799      0.074     -3.776      0.000      -0.425      -0.135
# ma.L1         -0.5771      0.069     -8.324      0.000      -0.713      -0.441
# sigma2         0.0036      0.000     12.859      0.000       0.003       0.004
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                18.83
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.16   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train=ap1[:-12]
test=ap1[-12:]
train

'''SARIMAX'''
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(train['Cost'],order=(0,1,1), seasonal_order=(0,1,0,12))
model_fit=model.fit()
test_prediction = model_fit.forecast(12)
test_prediction=pd.DataFrame(test_prediction)
new_index = test.index
test_prediction=test_prediction.set_index(new_index)
test_prediction.columns=['Cost']


plt.plot(train['Cost'],label='TRAIN')
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Train, Test and Predicted Test using SARIMAX');
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Test and Predicted Test using SARIMAX');

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
def cal_error(test, test_prediction):
  print(f'Mean Absolute Error = {mean_absolute_error(test,test_prediction)}')
  print(f'Mean Squared Error = {mean_squared_error(test,test_prediction)}')
  print(f'Mean Absolute Percentage Error = {mape(np.array(test),np.array(test_prediction) )}')

def mape(actual,pred):
    return round(np.mean(np.abs((actual - pred) / actual)) * 100 ,3)

cal_error(test, test_prediction)
# Out:
# Mean Absolute Error = 0.0909268178421108
# Mean Squared Error = 0.01324054374415085
# Mean Absolute Percentage Error = 10.229

# %%
test
# Out:
#               Cost
# Month
# 2007 Jul  0.954144
# 2007 Aug  1.078219
# 2007 Sep  1.110982
# 2007 Oct  1.109979
# 2007 Nov  1.163534
# 2007 Dec  1.176589
# 2008 Jan  1.219941
# 2008 Feb  0.761822
# 2008 Mar  0.649435
# 2008 Apr  0.827887
# 2008 May  0.816255
# 2008 Jun  0.762137

# %%
'''According to the given statistics,  MAPE <10, is Excellent, MAPE <20 is Good. So, it is still good. '''

print()
'''The additive method is preferred when the seasonal variations are roughly constant through the series, 
while the multiplicative method is preferred when the seasonal variations are changing proportional t
o the level of the series.'''
print()

# %%
'''ExponentialSmoothing'''

from statsmodels.tsa.holtwinters import ExponentialSmoothing


''' since the magnitute of the seasonality is different, I used multiplicative '''


fitted_model = ExponentialSmoothing(train,trend='mul',seasonal='mul',seasonal_periods=12).fit()
test_prediction = ExponentialSmoothing(train,trend='mul',seasonal='mul',seasonal_periods=12).fit().forecast(12)
test_prediction=pd.DataFrame(test_prediction)
new_index = test.index
test_prediction=test_prediction.set_index(new_index)
test_prediction.columns=['Cost']


plt.plot(train['Cost'],label='TRAIN')
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Train, Test and Predicted Test using Holt Winters');
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Test and Predicted Test using Holt Winters');

# %%
cal_error(test, test_prediction)
# Out:
# Mean Absolute Error = 0.06513513772255573
# Mean Squared Error = 0.007204818383369751
# Mean Absolute Percentage Error = 7.596

# %%
'''ExponentialSmoothing is better than SARIMAX'''
# Out:
# 'ExponentialSmoothing is better than SARIMAX'

# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel


'''Here again, I used multiplicative''' 

test_prediction=ETSModel(train['Cost'],error='mul', trend='mul',seasonal='mul',damped_trend=True, seasonal_periods=12).fit().forecast(12)
test_prediction=pd.DataFrame(test_prediction)
new_index = test.index
test_prediction=test_prediction.set_index(new_index)
test_prediction.columns=['Cost']


plt.plot(train['Cost'],label='TRAIN')
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Train, Test and Predicted Test using ETS');
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Test and Predicted Test using ETS');

# %%
cal_error(test, test_prediction)
# Out:
# Mean Absolute Error = 0.07535343950389495
# Mean Squared Error = 0.008976048645058084
# Mean Absolute Percentage Error = 8.513

# %%
''' It is still better than SARIMAX,  but SMOOTHING is still the best'''
# Out:
# ' It is still better than SARIMAX,  but SMOOTHING is still the best'

# %%
from tbats import TBATS
estimator = TBATS(
    seasonal_periods=[12],
    use_arma_errors=False, 
    use_box_cox=False #will not use Box-Cox
)
model = estimator.fit(train)
test_prediction = model.forecast(steps=12)

test_prediction=pd.DataFrame(test_prediction)
new_index = test.index
test_prediction=test_prediction.set_index(new_index)
test_prediction.columns=['Cost']


plt.plot(train['Cost'],label='TRAIN')
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Train, Test and Predicted Test using TBATS');

# %%
plt.plot(test['Cost'],label='TEST')
plt.plot(test_prediction,label='FORECAST')
plt.legend(loc="upper left")
plt.title('Test and Predicted Test using TBATS');

# %%
cal_error(test, test_prediction)
# Out:
# Mean Absolute Error = 0.10345093536180565
# Mean Squared Error = 0.012378694237250612
# Mean Absolute Percentage Error = 10.816

# %%
'''STILL SMOOTHING is the best, as the errors are a bit high'''
# Out:
# 'STILL SMOOTHING is the best, as the errors are a bit high'

# %%
ap2['HWES3_MUL'] = ExponentialSmoothing(ap2['Cost'],trend='mul',seasonal='mul',seasonal_periods=12).fit().fittedvalues
ap2[['Cost','HWES3_MUL']].plot(title='Holt Winters Triple Exponential Smoothing: Multiplicative Seasonality');
ap2[['Cost','HWES3_MUL']][-12:].plot(title='Holt Winters Triple Exponential Smoothing: Multiplicative Seasonality');
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
ap2['HWES3_MUL'] = ExponentialSmoothing(ap2['Cost'],trend='add',seasonal='add',seasonal_periods=12).fit().fittedvalues
ap2[['Cost','HWES3_MUL']].plot(title='Holt Winters Triple Exponential Smoothing: Multiplicative Seasonality');
ap2[['Cost','HWES3_MUL']][-12:].plot(title='Holt Winters Triple Exponential Smoothing: Multiplicative Seasonality');
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
#Q10:

#ExponentialSmoothing
